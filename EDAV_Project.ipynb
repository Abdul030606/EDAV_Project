# %%
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (8, 5)

# %%
import pandas as pd
import random

items = ['Tea', 'Coffee', 'Sandwich', 'Maggi', 'Juice', 'Burger', 'Samosa',
         'Idli', 'Dosa', 'Pasta', 'Vada Pav', 'Salad']
categories = {
    'Tea': 'Beverages', 'Coffee': 'Beverages', 'Juice': 'Beverages',
    'Sandwich': 'Snacks', 'Maggi': 'Snacks', 'Burger': 'Snacks', 'Samosa': 'Snacks', 'Vada Pav': 'Snacks',
    'Idli': 'Meals', 'Dosa': 'Meals', 'Pasta': 'Meals', 'Salad': 'Healthy'
}
time_slots = ['Morning', 'Afternoon', 'Evening']

data = []
for _ in range(50):
    item = random.choice(items)
    category = random.choice([
        categories[item].lower(),
        categories[item].upper(),
        categories[item].capitalize()
    ])
    price = random.randint(10, 100)
    quantity_sold = random.randint(1, 30)
    time_slot = random.choice(time_slots)
    data.append([item, category, price, quantity_sold, time_slot])

df = pd.DataFrame(data, columns=["item", "category", "price", "quantity_sold", "time_slot"])
df.to_csv("canteen_sales.csv", index=False)

pd.set_option('display.max_rows', None)
print("canteen_sales.csv created successfully")
print(df)
# Out:
# canteen_sales.csv created successfully
#         item   category  price  quantity_sold  time_slot
# 0       Dosa      Meals     32              2    Morning
# 1     Samosa     snacks     90             11    Evening
# 2       Idli      Meals     56             20    Evening
# 3     Burger     snacks     16             15    Morning
# 4       Idli      Meals     31              2    Evening
# 5      Salad    healthy     97             27    Evening
# 6      Salad    Healthy     21             27    Evening
# 7     Samosa     snacks     21             15    Evening
# 8   Vada Pav     snacks     10              7  Afternoon
# 9       Dosa      meals     48             19  Afternoon
# 10  Sandwich     snacks     56             25    Evening
# 11     Pasta      Meals     87             24    Morning
# 12  Sandwich     snacks     61              7    Morning
# 13      Dosa      Meals     73             28    Evening
# 14      Dosa      meals     58              2    Evening
# 15      Dosa      MEALS     28             24    Evening
# 16     Pasta      meals     70             25    Morning
# 17     Maggi     Snacks     55             17  Afternoon
# 18    Samosa     SNACKS     36             14    Evening
# 19    Samosa     snacks     40             27    Evening
# 20     Salad    healthy     18             30    Morning
# 21  Vada Pav     Snacks     57             27  Afternoon
# 22       Tea  BEVERAGES     49             12    Morning
# 23      Dosa      Meals     21              4    Evening
# 24     Pasta      MEALS     39             30  Afternoon
# 25  Sandwich     Snacks     26              4    Evening
# 26       Tea  Beverages     12              9    Evening
# 27    Samosa     Snacks    100             30    Evening
# 28    Burger     Snacks     78             20    Morning
# 29     Juice  Beverages     39             20  Afternoon
# 30       Tea  BEVERAGES     26             13    Evening
# 31      Idli      Meals     95             11  Afternoon
# 32  Sandwich     snacks     94             20  Afternoon
# 33  Vada Pav     snacks     98             14    Morning
# 34     Pasta      MEALS     85             11    Morning
# 35    Burger     SNACKS     73              1    Morning
# 36     Salad    healthy     84             14    Evening
# 37     Pasta      meals     45              6  Afternoon
# 38    Coffee  beverages     62             26  Afternoon
# 39      Idli      Meals     35              5    Morning
# 40     Juice  beverages     25             17    Evening
# 41     Maggi     snacks     65             11    Evening
# 42  Sandwich     SNACKS     75             10    Evening
# 43    Samosa     snacks     32             15    Morning
# 44      Idli      meals     90             15  Afternoon
# 45    Coffee  beverages     11             29    Morning
# 46      Dosa      meals     62             14    Morning
# 47    Burger     Snacks     87             17    Evening
# 48    Samosa     snacks     92             22  Afternoon
# 49    Burger     snacks     29             11    Morning

# %%
df = pd.read_csv("canteen_sales.csv")
print("Initial Data:")
df['category'] = df['category'].str.capitalize()
print(df.head())
# Out:
# Initial Data:
#     item   category  price  quantity_sold  time_slot
# 0  Maggi     Snacks     82              3    Morning
# 1  Pasta      Meals     82              8    Evening
# 2    Tea  Beverages     61             20  Afternoon
# 3  Juice  Beverages     65              3    Evening
# 4    Tea  Beverages     60              6  Afternoon

# %%
df['total_sales'] = df['price'] * df['quantity_sold']
category_sales = df.groupby('category')['total_sales'].sum().reset_index()
print(category_sales)

plt.figure(figsize=(7, 4))
sns.barplot(data=category_sales, x='category', y='total_sales', palette='viridis')
plt.title('Total Sales by Category')
plt.ylabel('Sales (₹)')
plt.xlabel('Category')
plt.show()
# Out:
#      category  total_sales
# 0   BEVERAGES          926
# 1   Beverages          888
# 2     Healthy          567
# 3       MEALS         2777
# 4       Meals         6682
# 5      SNACKS         1327
# 6      Snacks         8617
# 7   beverages         2356
# 8     healthy         4335
# 9       meals         5266
# 10     snacks        11312
# C:\Users\abdul\AppData\Local\Temp\ipykernel_22560\3245275817.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=category_sales, x='category', y='total_sales', palette='viridis')

# %%
time_demand = df.groupby('time_slot')['quantity_sold'].sum().reset_index().sort_values(by='quantity_sold', ascending=False)
print(time_demand)

plt.figure(figsize=(7, 4))
sns.barplot(data=time_demand, x='time_slot', y='quantity_sold', palette='coolwarm')
plt.title('Peak Demand by Time Slot')
plt.xlabel('Time Slot')
plt.ylabel('Quantity Sold')
plt.show()
# Out:
#    time_slot  quantity_sold
# 1    Evening            351
# 2    Morning            235
# 0  Afternoon            220
# C:\Users\abdul\AppData\Local\Temp\ipykernel_22560\3774620992.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=time_demand, x='time_slot', y='quantity_sold', palette='coolwarm')

# %%
corr = df['price'].corr(df['quantity_sold'])
print(f"Correlation between Price and Quantity Sold: {corr:.2f}")

plt.figure(figsize=(6, 4))
sns.scatterplot(data=df, x='price', y='quantity_sold')
plt.title('Price vs Quantity Sold')
plt.xlabel('Price (₹)')
plt.ylabel('Quantity Sold')
plt.show()
# Out:
# Correlation between Price and Quantity Sold: 0.14

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(data=category_sales, x='category', y='total_sales', marker='o', linewidth=2)
plt.title('Category-wise Sales Trend')
plt.xlabel('Category')
plt.ylabel('Total Sales (₹)')
plt.show()
